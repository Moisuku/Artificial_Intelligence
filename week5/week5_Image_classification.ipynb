# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

import matplotlib.pyplot as plt
from sklearn import datasets, metrics
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 파일 불러오기

# %%
digits = datasets.load_digits()
plt.imshow(digits.images[0], cmap=plt.cm.gray_r, interpolation='nearest')

# %% [markdown]
# # 1차원 배열로 변경

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))

# %% [markdown]
# # 데이터 분할

# %%
# 훈련/테스트 데이터 분할 
X_train, X_test, y_train, y_test = train_test_split(data, digits.target, test_size=0.2)

# shape를 통해 제대로 분리 됐는지 확인
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (1437, 64) (360, 64) (1437,) (360,)

# %% [markdown]
# # SVM

# %%
# SVM
clf_svm = SVC(random_state=0)
clf_svm.fit(X_train, y_train)

pred_svm = clf_svm.predict(X_test)

print("\n--- SVM Classifier ---")
scores = metrics.accuracy_score(y_test, pred_svm)
print(scores)
# Out:
# --- SVM Classifier ---
# 0.9916666666666667

# %% [markdown]
# # 이미지 출력 후 예측 값 확인

# %%
# 1차원 배열을 다시 8x8로 되돌리기
plt.imshow(X_test[10].reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
y_pred = clf_svm.predict([X_test[10]])
print(y_pred)
# Out:
# [2]

# %% [markdown]
# # DecisionTree / DT

# %%
# DecisionTree / DT
clf_dt = DecisionTreeClassifier(random_state=0)
clf_dt.fit(X_train, y_train)

pred_dt = clf_dt.predict(X_test)

print ("\n--- Decision Tree Classifier ---")
scores = metrics.accuracy_score(y_test, pred_dt)
print(scores)
# Out:
# --- Decision Tree Classifier ---
# 0.8666666666666667

# %%
# 1차원 배열을 다시 8x8로 되돌리기
plt.imshow(X_test[10].reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
y_pred = clf_dt.predict([X_test[10]])
print(y_pred)
# Out:
# [2]

# %% [markdown]
# # RandomForest / RF

# %%
# RandomForest / RF
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)

pred_rf = rf.predict(X_test)

print ("\n--- Random Forest ---")
scores = metrics.accuracy_score(y_test, pred_rf)
print(scores)
# Out:
# --- Random Forest ---
# 0.9722222222222222

# %%
# 1차원 배열을 다시 8x8로 되돌리기
plt.imshow(X_test[10].reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
y_pred = rf.predict([X_test[10]])
print(y_pred)
# Out:
# [2]

# %% [markdown]
# # KNN

# %%
# KNN
knn = KNeighborsClassifier(n_neighbors=6)
knn.fit(X_train, y_train)

pred_knn = knn.predict(X_test)

print ("\n--- KNN ---")
scores = metrics.accuracy_score(y_test, pred_knn)
print(scores)
# Out:
# --- KNN ---
# 0.9833333333333333

# %%
# 1차원 배열을 다시 8x8로 되돌리기
plt.imshow(X_test[10].reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
y_pred = knn.predict([X_test[10]])
print(y_pred)
# Out:
# [2]

# %% [markdown]
# # LogisticRegression

# %%
# LogisticRegression / LR
lr = LogisticRegression(random_state=0)
lr.fit(X_train, y_train)

pred_lr = lr.predict(X_test)

print ("\n--- LR ---")
scores = metrics.accuracy_score(y_test, pred_lr)
print(scores)
# Out:
# --- LR ---
# 0.9694444444444444
# C:\Users\송민수\AppData\Roaming\Python\Python312\site-packages\sklearn\linear_model\_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# 1차원 배열을 다시 8x8로 되돌리기
plt.imshow(X_test[10].reshape(8,8), cmap=plt.cm.gray_r, interpolation='nearest')
y_pred = lr.predict([X_test[10]])
print(y_pred)
# Out:
# [2]
